# %% [markdown]
# <a href="https://colab.research.google.com/github/lovishcode15/Python-Projects/blob/main/Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import NewType
"""pt_data={
    "patient1": {"name":"Aman","Health no":"123456789", "appt time":"seeing Dr. JA at 1:30 pm"},
    "patient2": {"name":"param","Health no":"987654321", "appt time":"seeing Dr. JA at 1:45 pm"},
}

def find_appt(search_name, search_healthno):
    for patient_key, details in pt_data.items(): # Iterate over key-value pairs
        if (details["name"].lower() == search_name.lower() and details["Health no"] == search_healthno):
            return details # Return the entire patient details dictionary if found
    return None

name_input = input("enter a name:")
healthno_input = input("enter a health no:")

found_patient_details = find_appt(name_input, healthno_input)

if found_patient_details:
    print("patient found:")
    print(found_patient_details["appt time"]) # Access appt time from the returned details
else:
    print("pt not found")

#project #2
#How to process referral using keywords
Doctors={"Cardiology":{"doctor":"Lovish", "wait time": "4-6 months"},
         "Neurology":{"doctor":"Ritika", "wait time": "8 months"},
         "GI":{"doctor":"Parveen", "wait time": "12 months"}}
Keywords={"Cardiology":["chest pain","SOB","heart attack","myocardia"],
          "Neurology":["coodination", "Neurons", "memory", "migraine"],
          "GI":["stomach pain", "GERD", "constipation","stool"]}

def find_speciality(referral):
    referral=referral.lower()
    for speciality_name, keywords_list in Keywords.items(): # Correctly unpack speciality name and list of keywords
        for individual_keyword in keywords_list: # Iterate over individual keywords (strings)
            if individual_keyword.lower() in referral: # Check if the string keyword is in the referral string
                return speciality_name # Return the speciality name if a match is found
    return None # Return None only if no matching speciality is found after all checks

def find_doctor(referral):
    speciality=find_speciality(referral)
    if speciality is None: # Corrected: Check if speciality is actually None
        return None, None # Return None for doctor and wait_time if no speciality found

    doctor=Doctors[speciality]["doctor"]
    wait_time=Doctors[speciality]["wait time"]
    return doctor, wait_time


referral=input("enter a referral:")
referral = find_doctor(referral) # Unpack the tuple directly

if referral: # Check if a doctor was found (i.e., not None)
    print(f"Doctor: {found_doctor_name}, Wait time: {found_wait_time}")
else:
    print("referral rejected")
#project 3
Number1=int(input("enter a 1st no:"))
Number2= int(input("enter a 2nd no:"))
operations= input("enter a arithmetic operation:")

if operations== "addition":
    Number3=Number1+Number2
    print(Number3)
elif operations=="subtraction":
    Number3=Number1-Number2
    print(Number3)
elif operations=="multiplication":
    Number3=Number1*Number2
    print(Number3)
elif operations=="division":
    if Number1 and Number2==0:
        print("error")
    else:
        Number3=Number1/Number2
        print(Number3)"""
#project 4
def add_task(task_list, new_task):
    task_list.append(new_task)
    print(task_list)
def view_task(task_list):
    print(task_list)
def complete_task(task_list, completed_task):
    task_list.remove(completedtask)
    print(task_list)
def clear_task(task_list, delete_task):
    task_list.clear(deletetask)
    print(task_list)
def Exit():
    print("no task")



Tasks= ["python project", "Reddit", "Quora", "prep meal"]
Selectfunction=input("enter a function:")


while True:
    if Selectfunction=="Add":
        newtask=input("enter a new task:")
        add_task(Tasks, newtask)
    elif Selectfunction=="View":
        view_task(Tasks)
    elif Selectfunction=="Complete":
        completedtask=input("enter a completed task:")
        complete_task(Tasks, completedtask)
    elif Selectfunction=="Delete":
        deletetask=input("enter a deleted task:")
        clear_task(Tasks, deletetask)
    else:
        Exit()
        break
